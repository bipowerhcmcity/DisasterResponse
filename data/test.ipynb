# %%
import pandas as pd
df_messages = pd.read_csv("disaster_messages.csv")
df_categories = pd.read_csv("disaster_categories.csv")

df = df_messages.merge(df_categories NUMBER NUMBER,on="id")
df

# %%
#Cleaning data:
df.isna().sum()

# %%
# The original is missing so many values NUMBER, so I decide eliminate the column original:
df.drop("original" NUMBER, inplace=True NUMBER, axis=1)

# %%
df

# %%
# Remove also ID column and check the duplicate row
df.drop("id" NUMBER, inplace=True NUMBER, axis=1)

# %%
df[df.duplicated()]

# %%
df = df.drop_duplicates(keep='first')

# %%
df

# %%
## Make the categories column into dummy value: 

def get_value():
    output = []
    for row in df.categories:
        ls_categories = row.split(";")
        output.append({value.split("-")[0]:value.split("-")[1] for value in ls_categories})
    print(output)
    return pd.DataFrame(output)
get_value()

# %%
df = pd.concat([df NUMBER,get_value()])
df.drop("categories" NUMBER, inplace=True NUMBER, axis=1)

# %%
df.columns
# Out:
# Index(['message', 'genre', 'categories', 'related', 'request', 'offer',
#        'aid_related', 'medical_help', 'medical_products', 'search_and_rescue',
#        'security', 'military', 'child_alone', 'water', 'food', 'shelter',
#        'clothing', 'money', 'missing_people', 'refugees', 'death', 'other_aid',
#        'infrastructure_related', 'transport', 'buildings', 'electricity',
#        'tools', 'hospitals', 'shops', 'aid_centers', 'other_infrastructure',
#        'weather_related', 'floods', 'storm', 'fire', 'earthquake', 'cold',
#        'other_weather', 'direct_report'],
#       dtype='object')

# %%
len(['related', 'request', 'offer',
       'aid_related', 'medical_help', 'medical_products', 'search_and_rescue',
       'security', 'military', 'child_alone', 'water', 'food', 'shelter',
       'clothing', 'money', 'missing_people', 'refugees', 'death', 'other_aid',
       'infrastructure_related', 'transport', 'buildings', 'electricity',
       'tools', 'hospitals', 'shops', 'aid_centers', 'other_infrastructure',
       'weather_related', 'floods', 'storm', 'fire', 'earthquake', 'cold',
       'other_weather', 'direct_report'])
# Out:
# 36

# %%
df
# Out:
#                                                  message   genre  \
# 0      Weather update - a cold front from Cuba that c...  direct
# 1                Is the Hurricane over or is it not over  direct
# 2                        Looking for someone but no name  direct
# 3      UN reports Leogane 80-90 destroyed. Only Hospi...  direct
# 4      says: west side of Haiti, rest of the country ...  direct
# ...                                                  ...     ...
# 26210                                                NaN     NaN
# 26211                                                NaN     NaN
# 26212                                                NaN     NaN
# 26213                                                NaN     NaN
# 26214                                                NaN     NaN
#
#                                               categories related request  \
# 0      related-1;request-0;offer-0;aid_related-0;medi...     NaN     NaN
# ...

# %%
import sqlite3 
import pandas as pd
conn = sqlite3.connect("../DisasterResponse.db")
df = pd.read_sql("Select * from disaster_data",con=conn)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File c:\Users\Public\anaconda3\envs\test\lib\site-packages\pandas\io\sql.py:2018, in SQLiteDatabase.execute(self, *args, **kwargs)
#    2017 try:
# -> 2018     cur.execute(*args, **kwargs)
#    2019     return cur
#
# OperationalError: no such table: disaster_data
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[2], line 4
#       2 import pandas as pd
#       3 conn = sqlite3.connect("DisasterResponse.db")
# ----> 4 df = pd.read_sql("Select * from disaster_data",con=conn)
#
# File c:\Users\Public\anaconda3\envs\test\lib\site-packages\pandas\io\sql.py:564, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     561 pandas_sql = pandasSQL_builder(con)
# ...
